# %%
import math
import xarray as xr
import cartopy.crs as ccrs
import matplotlib as mpl
from matplotlib import pyplot as plt 
import matplotlib.pylab as plt
import matplotlib.path as mpath
from matplotlib.pyplot import figure
import numpy as np
import cartopy.feature as cfeature
from matplotlib.cm import get_cmap
import pyproj
import utm
import pandas as pd 
import traceback 
from pathlib import Path  
import os  
import numpy.ma as ma
import netCDF4 as nc
from netCDF4 import Dataset
import glob
import datetime as dt
import metpy.calc as mpcalc
from metpy.units import units
from metpy.cbook import get_test_data
from metpy.io import metar
from metpy.plots.declarative import (BarbPlot, ContourPlot, FilledContourPlot, MapPanel,
                                     PanelContainer, PlotObs)
from netCDF4 import date2num,num2date
import wrf
from wrf import (getvar, interplevel, to_np, latlon_coords, get_cartopy,
                 cartopy_xlim, cartopy_ylim)
from wrf import getvar, interplevel, to_np, get_basemap, latlon_coords

# %%
sstRun_6 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_06_00_00')
sstRun_7 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_07_00_00') 
sstRun_8 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_08_00_00') 
sstRun_9 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_09_00_00') 
sstRun_10 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_10_00_00') 
sstRun_11 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_11_00_00') 
sstRun_12 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_12_00_00') 
sstRun_13 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_13_00_00') 
sstRun_14 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_14_00_00') 
sstRun_15 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_15_00_00') 
sstRun_16 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_16_00_00') 
sstRun_17 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_17_00_00') 
sstRun_18 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_18_00_00') 
sstRun_19 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_19_00_00') 
sstRun_20 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_20_00_00') 
sstRun_21 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_21_00_00') 
sstRun_22 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_22_00_00') 
sstRun_23 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-25_23_00_00') 
sstRun_24 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunSST/wrfout_d03_2018-03-26_00_00_00')

# %%
sstCurRun_6 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_06_00_00')
sstCurRun_7 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_07_00_00')
sstCurRun_8 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_08_00_00')
sstCurRun_9 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_09_00_00')
sstCurRun_10 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_10_00_00')
sstCurRun_11 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_11_00_00')
sstCurRun_12 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_12_00_00')
sstCurRun_13 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_13_00_00')
sstCurRun_14 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_14_00_00')
sstCurRun_15 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_15_00_00')
sstCurRun_16 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_16_00_00')
sstCurRun_17 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_17_00_00')
sstCurRun_18 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_18_00_00')
sstCurRun_19 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_19_00_00')
sstCurRun_20 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_20_00_00')
sstCurRun_21 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_21_00_00')
sstCurRun_22 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_22_00_00')
sstCurRun_23 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-25_23_00_00')
sstCurRun_24 = xr.open_dataset('/Users/Anna/Desktop/WRF/shortRunCurrent/wrfout_d03_2018-03-26_00_00_00')

# %%
xlat = sstRun_6.XLAT.values
xlon = sstRun_6.XLONG.values
print('xlat shape:', xlat.shape, 'xlon shape: ', xlon.shape)

#sst PBLH
sst_pblh_6 = sstRun_6.PBLH.values
sst_pblh_7 = sstRun_7.PBLH.values
sst_pblh_8 = sstRun_8.PBLH.values
sst_pblh_9 = sstRun_9.PBLH.values
sst_pblh_10 = sstRun_10.PBLH.values
sst_pblh_11 = sstRun_11.PBLH.values
sst_pblh_12 = sstRun_12.PBLH.values
sst_pblh_13 = sstRun_13.PBLH.values
sst_pblh_14 = sstRun_14.PBLH.values
sst_pblh_15 = sstRun_15.PBLH.values
sst_pblh_16 = sstRun_16.PBLH.values
sst_pblh_17 = sstRun_17.PBLH.values 
sst_pblh_18 = sstRun_18.PBLH.values
sst_pblh_19 = sstRun_19.PBLH.values
sst_pblh_20 = sstRun_20.PBLH.values
sst_pblh_21 = sstRun_21.PBLH.values
sst_pblh_22 = sstRun_22.PBLH.values
sst_pblh_23 = sstRun_23.PBLH.values
sst_pblh_24 = sstRun_24.PBLH.values
print('pblh shape: ', sst_pblh_6.shape)

#currents PBLH
cur_pblh_6 = sstCurRun_6.PBLH.values
cur_pblh_7 = sstCurRun_7.PBLH.values
cur_pblh_8 = sstCurRun_8.PBLH.values
cur_pblh_9 = sstCurRun_9.PBLH.values
cur_pblh_10 = sstCurRun_10.PBLH.values
cur_pblh_11 = sstCurRun_11.PBLH.values
cur_pblh_12 = sstCurRun_12.PBLH.values
cur_pblh_13 = sstCurRun_13.PBLH.values
cur_pblh_14 = sstCurRun_14.PBLH.values
cur_pblh_15 = sstCurRun_15.PBLH.values
cur_pblh_16 = sstCurRun_16.PBLH.values
cur_pblh_17 = sstCurRun_17.PBLH.values 
cur_pblh_18 = sstCurRun_18.PBLH.values
cur_pblh_19 = sstCurRun_19.PBLH.values
cur_pblh_20 = sstCurRun_20.PBLH.values
cur_pblh_21 = sstCurRun_21.PBLH.values
cur_pblh_22 = sstCurRun_22.PBLH.values
cur_pblh_23 = sstCurRun_23.PBLH.values
cur_pblh_24 = sstCurRun_24.PBLH.values
print('pblh shape: ', cur_pblh_6.shape)
