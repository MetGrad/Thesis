# %%
import xarray as xr
import cartopy.crs as ccrs
from matplotlib import pyplot as plt 
import matplotlib.pylab as plt
import matplotlib.path as mpath
import numpy as np
import cartopy.feature as cfeature
import metpy.calc as mpcalc
from metpy.units import units

# %%
#March 26
ds26_1 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180326_084656_0001-0110_line01.L2.nc')
ds26_2 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180326_084656_0118-0170_line02.L2.nc')
ds26_3 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180326_084656_0180-0227_line03.L2.nc')
ds26_4 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180326_084656_0238-0296_line04.L2.nc')
ds26_5 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180326_084656_0306-0348_line05.L2.nc')
ds26_6 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180326_084656_0360-0375_line06.L2.nc')
ds26_7 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180326_084656_0377-0419_line07.L2.nc')
ds26_8 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180326_084656_0429-0470_line08.L2.nc')
ds26_9 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180326_084656_0485-0533_line09.L2.nc')
ds26_10 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180326_084656_0543-0581_line10.L2.nc')
ds26_11=xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180326_084656_0588-0682_line11.L2.nc')

#print(ds26_1.variables)

#March 25
ds25_1 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180325_084330_0036-0111_line01.L2.nc')
ds25_2 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180325_084330_0119-0174_line02.L2.nc')
ds25_3 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180325_084330_0189-0236_line03.L2.nc')
ds25_4 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180325_084330_0249-0312_line04.L2.nc')
ds25_5 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180325_084330_0326-0368_line05.L2.nc')
ds25_6 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180325_084330_0380-0436_line06.L2.nc')
ds25_7 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180325_084330_0450-0490_line07.L2.nc')
ds25_8 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180325_084330_0504-0552_line08.L2.nc')
ds25_9 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180325_084330_0565-0602_line09.L2.nc')
ds25_10 = xr.open_dataset('/Users/Anna/Desktop/MSMET/Thesis/JPL_March22/20180325_084330_0609-0696_line10.L2.nc')

# %%
#March 25
Lat25_1=ds25_1.latitude.values
Lon25_1=ds25_1.longitude.values
Lat25_2=ds25_2.latitude.values
Lon25_2=ds25_2.longitude.values
Lat25_3=ds25_3.latitude.values
Lon25_3=ds25_3.longitude.values
Lat25_4=ds25_4.latitude.values
Lon25_4=ds25_4.longitude.values
Lat25_5=ds25_5.latitude.values
Lon25_5=ds25_5.longitude.values
Lat25_6=ds25_6.latitude.values
Lon25_6=ds25_6.longitude.values
Lat25_7=ds25_7.latitude.values
Lon25_7=ds25_7.longitude.values
Lat25_8=ds25_8.latitude.values
Lon25_8=ds25_8.longitude.values
Lat25_9=ds25_9.latitude.values
Lon25_9=ds25_9.longitude.values
Lat25_10=ds25_10.latitude.values
Lon25_10=ds25_10.longitude.values

#wind speed & direction 25
windSp25_1=ds25_1.wind_speed.values 
windDir25_1=ds25_1.wind_dir.values
windSp25_2=ds25_2.wind_speed.values 
windDir25_2=ds25_2.wind_dir.values
windSp25_3=ds25_3.wind_speed.values 
windDir25_3=ds25_3.wind_dir.values
windSp25_4=ds25_4.wind_speed.values 
windDir25_4=ds25_4.wind_dir.values
windSp25_5=ds25_5.wind_speed.values 
windDir25_5=ds25_5.wind_dir.values
windSp25_6=ds25_6.wind_speed.values 
windDir25_6=ds25_6.wind_dir.values
windSp25_7=ds25_7.wind_speed.values 
windDir25_7=ds25_7.wind_dir.values
windSp25_8=ds25_8.wind_speed.values 
windDir25_8=ds25_8.wind_dir.values
windSp25_9=ds25_9.wind_speed.values 
windDir25_9=ds25_9.wind_dir.values
windSp25_10=ds25_10.wind_speed.values 
windDir25_10=ds25_10.wind_dir.values

#Get wind direction in math coord
wDirMath25_1=90-windDir25_1*(np.pi/180)
wDirMath25_2=90-windDir25_2*(np.pi/180)
wDirMath25_3=90-windDir25_3*(np.pi/180)
wDirMath25_4=90-windDir25_4*(np.pi/180)
wDirMath25_5=90-windDir25_5*(np.pi/180)
wDirMath25_6=90-windDir25_6*(np.pi/180)
wDirMath25_7=90-windDir25_7*(np.pi/180)
wDirMath25_8=90-windDir25_8*(np.pi/180)
wDirMath25_9=90-windDir25_9*(np.pi/180)
wDirMath25_10=90-windDir25_10*(np.pi/180)

#Calculate the U, V wind vector components from the speed and direction.
windComponents25_1=mpcalc.wind_components(windSp25_1*units('m/s'), wDirMath25_1)
windComponents25_2=mpcalc.wind_components(windSp25_2*units('m/s'), wDirMath25_2)
windComponents25_3=mpcalc.wind_components(windSp25_3*units('m/s'), wDirMath25_3)
windComponents25_4=mpcalc.wind_components(windSp25_4*units('m/s'), wDirMath25_4)
windComponents25_5=mpcalc.wind_components(windSp25_5*units('m/s'), wDirMath25_5)
windComponents25_6=mpcalc.wind_components(windSp25_6*units('m/s'), wDirMath25_6)
windComponents25_7=mpcalc.wind_components(windSp25_7*units('m/s'), wDirMath25_7)
windComponents25_8=mpcalc.wind_components(windSp25_8*units('m/s'), wDirMath25_8)
windComponents25_9=mpcalc.wind_components(windSp25_9*units('m/s'), wDirMath25_9)
windComponents25_10=mpcalc.wind_components(windSp25_10*units('m/s'), wDirMath25_10)

#Recalculate wind speed
windSpeed25_1=np.sqrt((windSp25_1*np.cos(wDirMath25_1*(180/np.pi)))**2+(windSp25_1*np.sin(wDirMath25_1*(180/np.pi)))**2)
windSpeed25_2=np.sqrt((windSp25_2*np.cos(wDirMath25_2*(180/np.pi)))**2+(windSp25_2*np.sin(wDirMath25_2*(180/np.pi)))**2)
windSpeed25_3=np.sqrt((windSp25_3*np.cos(wDirMath25_3*(180/np.pi)))**2+(windSp25_3*np.sin(wDirMath25_3*(180/np.pi)))**2)
windSpeed25_4=np.sqrt((windSp25_4*np.cos(wDirMath25_4*(180/np.pi)))**2+(windSp25_4*np.sin(wDirMath25_4*(180/np.pi)))**2)
windSpeed25_5=np.sqrt((windSp25_5*np.cos(wDirMath25_5*(180/np.pi)))**2+(windSp25_5*np.sin(wDirMath25_5*(180/np.pi)))**2)
windSpeed25_6=np.sqrt((windSp25_6*np.cos(wDirMath25_6*(180/np.pi)))**2+(windSp25_6*np.sin(wDirMath25_6*(180/np.pi)))**2)
windSpeed25_7=np.sqrt((windSp25_7*np.cos(wDirMath25_7*(180/np.pi)))**2+(windSp25_7*np.sin(wDirMath25_7*(180/np.pi)))**2)
windSpeed25_8=np.sqrt((windSp25_8*np.cos(wDirMath25_8*(180/np.pi)))**2+(windSp25_8*np.sin(wDirMath25_8*(180/np.pi)))**2)
windSpeed25_9=np.sqrt((windSp25_9*np.cos(wDirMath25_9*(180/np.pi)))**2+(windSp25_9*np.sin(wDirMath25_9*(180/np.pi)))**2)
windSpeed25_10=np.sqrt((windSp25_10*np.cos(wDirMath25_10*(180/np.pi)))**2+(windSp25_10*np.sin(wDirMath25_10*(180/np.pi)))**2)

#Get wind components 
wind25_U1=windSp25_1*np.cos(wDirMath25_1*(180/np.pi))
wind25_V1=windSp25_1*np.sin(wDirMath25_1*(180/np.pi))
wind25_U2=windSp25_2*np.cos(wDirMath25_2*(180/np.pi))
wind25_V2=windSp25_2*np.sin(wDirMath25_2*(180/np.pi))
wind25_U3=windSp25_3*np.cos(wDirMath25_3*(180/np.pi))
wind25_V3=windSp25_3*np.sin(wDirMath25_3*(180/np.pi))
wind25_U4=windSp25_4*np.cos(wDirMath25_4*(180/np.pi))
wind25_V4=windSp25_4*np.sin(wDirMath25_4*(180/np.pi))
wind25_U5=windSp25_5*np.cos(wDirMath25_5*(180/np.pi))
wind25_V5=windSp25_5*np.sin(wDirMath25_5*(180/np.pi))
wind25_U7=windSp25_7*np.cos(wDirMath25_7*(180/np.pi))
wind25_V7=windSp25_7*np.sin(wDirMath25_7*(180/np.pi))
wind25_U8=windSp25_8*np.cos(wDirMath25_8*(180/np.pi))
wind25_V8=windSp25_8*np.sin(wDirMath25_8*(180/np.pi))
wind25_U9=windSp25_9*np.cos(wDirMath25_9*(180/np.pi))
wind25_V9=windSp25_9*np.sin(wDirMath25_9*(180/np.pi))
wind25_U10=windSp25_10*np.cos(wDirMath25_10*(180/np.pi))
wind25_V10=windSp25_10*np.sin(wDirMath25_10*(180/np.pi))

#stress curl 25
stressCurl25_1=ds25_1.wind_stress_curl.values
stressCurl25_2=ds25_2.wind_stress_curl.values
stressCurl25_3=ds25_3.wind_stress_curl.values
stressCurl25_4=ds25_4.wind_stress_curl.values
stressCurl25_5=ds25_5.wind_stress_curl.values
stressCurl25_6=ds25_6.wind_stress_curl.values
stressCurl25_7=ds25_7.wind_stress_curl.values
stressCurl25_8=ds25_8.wind_stress_curl.values
stressCurl25_9=ds25_9.wind_stress_curl.values
stressCurl25_10=ds25_10.wind_stress_curl.values

#wind stress 25
tau25_U1=ds25_1.tau_x.values
tau25_V1=ds25_1.tau_y.values
tau25_U2=ds25_2.tau_x.values
tau25_V2=ds25_2.tau_y.values
tau25_U3=ds25_3.tau_x.values
tau25_V3=ds25_3.tau_y.values
tau25_U4=ds25_4.tau_x.values
tau25_V4=ds25_4.tau_y.values
tau25_U5=ds25_5.tau_x.values
tau25_V5=ds25_5.tau_y.values
tau25_U6=ds25_6.tau_x.values
tau25_V6=ds25_6.tau_y.values
tau25_U7=ds25_7.tau_x.values
tau25_V7=ds25_7.tau_y.values
tau25_U8=ds25_8.tau_x.values
tau25_V8=ds25_8.tau_y.values
tau25_U9=ds25_9.tau_x.values
tau25_V9=ds25_9.tau_y.values
tau25_U10=ds25_10.tau_x.values
tau25_V10=ds25_10.tau_y.values

stressMag25_1=np.sqrt(tau25_U1**2+tau25_V1**2)
stressMag25_2=np.sqrt(tau25_U2**2+tau25_V2**2)
stressMag25_3=np.sqrt(tau25_U3**2+tau25_V3**2)
stressMag25_4=np.sqrt(tau25_U4**2+tau25_V4**2)
stressMag25_5=np.sqrt(tau25_U5**2+tau25_V5**2)
stressMag25_6=np.sqrt(tau25_U6**2+tau25_V6**2)
stressMag25_7=np.sqrt(tau25_U7**2+tau25_V7**2)
stressMag25_8=np.sqrt(tau25_U8**2+tau25_V8**2)
stressMag25_9=np.sqrt(tau25_U9**2+tau25_V9**2)
stressMag25_10=np.sqrt(tau25_U10**2+tau25_V10**2)

#currents 25
uCur25_1=ds25_1.u_current.values
vCur25_1=ds25_1.v_current.values
uCur25_2=ds25_2.u_current.values
vCur25_2=ds25_2.v_current.values
uCur25_3=ds25_3.u_current.values
vCur25_3=ds25_3.v_current.values
uCur25_4=ds25_4.u_current.values
vCur25_4=ds25_4.v_current.values
uCur25_5=ds25_5.u_current.values
vCur25_5=ds25_5.v_current.values
uCur25_6=ds25_6.u_current.values
vCur25_6=ds25_6.v_current.values
uCur25_7=ds25_7.u_current.values
vCur25_7=ds25_7.v_current.values
uCur25_8=ds25_8.u_current.values
vCur25_8=ds25_8.v_current.values
uCur25_9=ds25_9.u_current.values
vCur25_9=ds25_9.v_current.values
uCur25_10=ds25_10.u_current.values
vCur25_10=ds25_10.v_current.values

curMag25_1=np.sqrt(uCur25_1**2+vCur25_1**2)
curMag25_2=np.sqrt(uCur25_2**2+vCur25_2**2)
curMag25_3=np.sqrt(uCur25_3**2+vCur25_3**2)
curMag25_4=np.sqrt(uCur25_4**2+vCur25_4**2)
curMag25_5=np.sqrt(uCur25_5**2+vCur25_5**2)
curMag25_6=np.sqrt(uCur25_6**2+vCur25_6**2)
curMag25_7=np.sqrt(uCur25_7**2+vCur25_7**2)
curMag25_8=np.sqrt(uCur25_8**2+vCur25_8**2)
curMag25_9=np.sqrt(uCur25_9**2+vCur25_9**2)
curMag25_10=np.sqrt(uCur25_10**2+vCur25_10**2)

#March 26
Lat26_1=ds26_1.latitude.values
Lon26_1=ds26_1.longitude.values
Lat26_2=ds26_2.latitude.values
Lon26_2=ds26_2.longitude.values
Lat26_3=ds26_3.latitude.values
Lon26_3=ds26_3.longitude.values
Lat26_4=ds26_4.latitude.values
Lon26_4=ds26_4.longitude.values
Lat26_5=ds26_5.latitude.values
Lon26_5=ds26_5.longitude.values
Lat26_6=ds26_6.latitude.values
Lon26_6=ds26_6.longitude.values
Lat26_7=ds26_7.latitude.values
Lon26_7=ds26_7.longitude.values
Lat26_8=ds26_8.latitude.values
Lon26_8=ds26_8.longitude.values
Lat26_9=ds26_9.latitude.values
Lon26_9=ds26_9.longitude.values
Lat26_10=ds26_10.latitude.values
Lon26_10=ds26_10.longitude.values
Lat26_11=ds26_11.latitude.values
Lon26_11=ds26_11.longitude.values

#currents 26
uCur26_1=ds26_1.u_current.values
vCur26_1=ds26_1.v_current.values
uCur26_2=ds26_2.u_current.values
vCur26_2=ds26_2.v_current.values
uCur26_3=ds26_3.u_current.values
vCur26_3=ds26_3.v_current.values
uCur26_4=ds26_4.u_current.values
vCur26_4=ds26_4.v_current.values
uCur26_5=ds26_5.u_current.values
vCur26_5=ds26_5.v_current.values
uCur26_6=ds26_6.u_current.values
vCur26_6=ds26_6.v_current.values
uCur26_7=ds26_7.u_current.values
vCur26_7=ds26_7.v_current.values
uCur26_8=ds26_8.u_current.values
vCur26_8=ds26_8.v_current.values
uCur26_9=ds26_9.u_current.values
vCur26_9=ds26_9.v_current.values
uCur26_10=ds26_10.u_current.values
vCur26_10=ds26_10.v_current.values
uCur26_11=ds26_11.u_current.values
vCur26_11=ds26_11.v_current.values

curMag26_1=np.sqrt(uCur26_1**2+vCur26_1**2)
curMag26_2=np.sqrt(uCur26_2**2+vCur26_2**2)
curMag26_3=np.sqrt(uCur26_3**2+vCur26_3**2)
curMag26_4=np.sqrt(uCur26_4**2+vCur26_4**2)
curMag26_5=np.sqrt(uCur26_5**2+vCur26_5**2)
curMag26_6=np.sqrt(uCur26_6**2+vCur26_6**2)
curMag26_7=np.sqrt(uCur26_7**2+vCur26_7**2)
curMag26_8=np.sqrt(uCur26_8**2+vCur26_8**2)
curMag26_9=np.sqrt(uCur26_9**2+vCur26_9**2)
curMag26_10=np.sqrt(uCur26_10**2+vCur26_10**2)
curMag26_11=np.sqrt(uCur26_11**2+vCur26_11**2)

#wind stress 26
tau26_U1=ds26_1.tau_x.values
tau26_V1=ds26_1.tau_y.values
tau26_U2=ds26_2.tau_x.values
tau26_V2=ds26_2.tau_y.values
tau26_U3=ds26_3.tau_x.values
tau26_V3=ds26_3.tau_y.values
tau26_U4=ds26_4.tau_x.values
tau26_V4=ds26_4.tau_y.values
tau26_U5=ds26_5.tau_x.values
tau26_V5=ds26_5.tau_y.values
tau26_U6=ds26_6.tau_x.values
tau26_V6=ds26_6.tau_y.values
tau26_U7=ds26_7.tau_x.values
tau26_V7=ds26_7.tau_y.values
tau26_U8=ds26_8.tau_x.values
tau26_V8=ds26_8.tau_y.values
tau26_U9=ds26_9.tau_x.values
tau26_V9=ds26_9.tau_y.values
tau26_U10=ds26_10.tau_x.values
tau26_V10=ds26_10.tau_y.values
tau26_U11=ds26_11.tau_x.values
tau26_V11=ds26_11.tau_y.values

stressMag26_1=np.sqrt(tau26_U1**2+tau26_V1**2)
stressMag26_2=np.sqrt(tau26_U2**2+tau26_V2**2)
stressMag26_3=np.sqrt(tau26_U3**2+tau26_V3**2)
stressMag26_4=np.sqrt(tau26_U4**2+tau26_V4**2)
stressMag26_5=np.sqrt(tau26_U5**2+tau26_V5**2)
stressMag26_6=np.sqrt(tau26_U6**2+tau26_V6**2)
stressMag26_7=np.sqrt(tau26_U7**2+tau26_V7**2)
stressMag26_8=np.sqrt(tau26_U8**2+tau26_V8**2)
stressMag26_9=np.sqrt(tau26_U9**2+tau26_V9**2)
stressMag26_10=np.sqrt(tau26_U10**2+tau26_V10**2)
stressMag26_11=np.sqrt(tau26_U11**2+tau26_V11**2)


#wind speed & direction 26
#Assign Wind speed & direction per dataset  
windSp26_1=ds26_1.wind_speed.values 
windDir26_1=ds26_1.wind_dir.values
windSp26_2=ds26_2.wind_speed.values 
windDir26_2=ds26_2.wind_dir.values
windSp26_3=ds26_3.wind_speed.values 
windDir26_3=ds26_3.wind_dir.values
windSp26_4=ds26_4.wind_speed.values 
windDir26_4=ds26_4.wind_dir.values
windSp26_5=ds26_5.wind_speed.values 
windDir26_5=ds26_5.wind_dir.values
windSp26_6=ds26_6.wind_speed.values 
windDir26_6=ds26_6.wind_dir.values
windSp26_7=ds26_7.wind_speed.values 
windDir26_7=ds26_7.wind_dir.values
windSp26_8=ds26_8.wind_speed.values 
windDir26_8=ds26_8.wind_dir.values
windSp26_9=ds26_9.wind_speed.values 
windDir26_9=ds26_9.wind_dir.values
windSp26_10=ds26_10.wind_speed.values 
windDir26_10=ds26_10.wind_dir.values
windSp26_11=ds26_11.wind_speed.values 
windDir26_11=ds26_11.wind_dir.values

#Get wind direction in math coord
wDirMath26_1=90-windDir26_1*(np.pi/180)
wDirMath26_2=90-windDir26_2*(np.pi/180)
wDirMath26_3=90-windDir26_3*(np.pi/180)
wDirMath26_4=90-windDir26_4*(np.pi/180)
wDirMath26_5=90-windDir26_5*(np.pi/180)
wDirMath26_6=90-windDir26_6*(np.pi/180)
wDirMath26_7=90-windDir26_7*(np.pi/180)
wDirMath26_8=90-windDir26_8*(np.pi/180)
wDirMath26_9=90-windDir26_9*(np.pi/180)
wDirMath26_10=90-windDir26_10*(np.pi/180)
wDirMath26_11=90-windDir26_11*(np.pi/180)

#Calculate the U, V wind vector components from the speed and direction.
#metpy.calc.wind_components(speed, wind_direction)
windComponents26_1=mpcalc.wind_components(windSp26_1*units('m/s'), wDirMath26_1)
windComponents26_2=mpcalc.wind_components(windSp26_2*units('m/s'), wDirMath26_2)
windComponents26_3=mpcalc.wind_components(windSp26_3*units('m/s'), wDirMath26_3)
windComponents26_4=mpcalc.wind_components(windSp26_4*units('m/s'), wDirMath26_4)
windComponents26_5=mpcalc.wind_components(windSp26_5*units('m/s'), wDirMath26_5)
windComponents26_6=mpcalc.wind_components(windSp26_6*units('m/s'), wDirMath26_6)
windComponents26_7=mpcalc.wind_components(windSp26_7*units('m/s'), wDirMath26_7)
windComponents26_8=mpcalc.wind_components(windSp26_8*units('m/s'), wDirMath26_8)
windComponents26_9=mpcalc.wind_components(windSp26_9*units('m/s'), wDirMath26_9)
windComponents26_10=mpcalc.wind_components(windSp26_10*units('m/s'), wDirMath26_10)
windComponents26_11=mpcalc.wind_components(windSp26_11*units('m/s'), wDirMath26_11)

#Recalculate wind speed
windSpeed26_1=np.sqrt((windSp26_1*np.cos(wDirMath26_1*(180/np.pi)))**2+(windSp26_1*np.sin(wDirMath26_1*(180/np.pi)))**2)
windSpeed26_2=np.sqrt((windSp26_2*np.cos(wDirMath26_2*(180/np.pi)))**2+(windSp26_2*np.sin(wDirMath26_2*(180/np.pi)))**2)
windSpeed26_3=np.sqrt((windSp26_3*np.cos(wDirMath26_3*(180/np.pi)))**2+(windSp26_3*np.sin(wDirMath26_3*(180/np.pi)))**2)
windSpeed26_4=np.sqrt((windSp26_4*np.cos(wDirMath26_4*(180/np.pi)))**2+(windSp26_4*np.sin(wDirMath26_4*(180/np.pi)))**2)
windSpeed26_5=np.sqrt((windSp26_5*np.cos(wDirMath26_5*(180/np.pi)))**2+(windSp26_5*np.sin(wDirMath26_5*(180/np.pi)))**2)
windSpeed26_6=np.sqrt((windSp26_6*np.cos(wDirMath26_6*(180/np.pi)))**2+(windSp26_6*np.sin(wDirMath26_6*(180/np.pi)))**2)
windSpeed26_7=np.sqrt((windSp26_7*np.cos(wDirMath26_7*(180/np.pi)))**2+(windSp26_7*np.sin(wDirMath26_7*(180/np.pi)))**2)
windSpeed26_8=np.sqrt((windSp26_8*np.cos(wDirMath26_8*(180/np.pi)))**2+(windSp26_8*np.sin(wDirMath26_8*(180/np.pi)))**2)
windSpeed26_9=np.sqrt((windSp26_9*np.cos(wDirMath26_9*(180/np.pi)))**2+(windSp26_9*np.sin(wDirMath26_9*(180/np.pi)))**2)
windSpeed26_10=np.sqrt((windSp26_10*np.cos(wDirMath26_10*(180/np.pi)))**2+(windSp26_10*np.sin(wDirMath26_10*(180/np.pi)))**2)
windSpeed26_11=np.sqrt((windSp26_11*np.cos(wDirMath26_11*(180/np.pi)))**2+(windSp26_11*np.sin(wDirMath26_11*(180/np.pi)))**2)

#Get wind components 
wind26_U1=windSp26_1*np.cos(wDirMath26_1*(180/np.pi))
wind26_V1=windSp26_1*np.sin(wDirMath26_1*(180/np.pi))
wind26_U2=windSp26_2*np.cos(wDirMath26_2*(180/np.pi))
wind26_V2=windSp26_2*np.sin(wDirMath26_2*(180/np.pi))
wind26_U3=windSp26_3*np.cos(wDirMath26_3*(180/np.pi))
wind26_V3=windSp26_3*np.sin(wDirMath26_3*(180/np.pi))
wind26_U4=windSp26_4*np.cos(wDirMath26_4*(180/np.pi))
wind26_V4=windSp26_4*np.sin(wDirMath26_4*(180/np.pi))
wind26_U5=windSp26_5*np.cos(wDirMath26_5*(180/np.pi))
wind26_V5=windSp26_5*np.sin(wDirMath26_5*(180/np.pi))
wind26_U7=windSp26_7*np.cos(wDirMath26_7*(180/np.pi))
wind26_V7=windSp26_7*np.sin(wDirMath26_7*(180/np.pi))
wind26_U8=windSp26_8*np.cos(wDirMath26_8*(180/np.pi))
wind26_V8=windSp26_8*np.sin(wDirMath26_8*(180/np.pi))
wind26_U9=windSp26_9*np.cos(wDirMath26_9*(180/np.pi))
wind26_V9=windSp26_9*np.sin(wDirMath26_9*(180/np.pi))
wind26_U10=windSp26_10*np.cos(wDirMath26_10*(180/np.pi))
wind26_V10=windSp26_10*np.sin(wDirMath26_10*(180/np.pi))
wind26_U11=windSp26_11*np.cos(wDirMath26_11*(180/np.pi))
wind26_V11=windSp26_11*np.sin(wDirMath26_11*(180/np.pi))

#stress curl 26
stressCurl26_1=ds26_1.wind_stress_curl.values
stressCurl26_2=ds26_2.wind_stress_curl.values
stressCurl26_3=ds26_3.wind_stress_curl.values
stressCurl26_4=ds26_4.wind_stress_curl.values
stressCurl26_5=ds26_5.wind_stress_curl.values
stressCurl26_6=ds26_6.wind_stress_curl.values
stressCurl26_7=ds26_7.wind_stress_curl.values
stressCurl26_8=ds26_8.wind_stress_curl.values
stressCurl26_9=ds26_9.wind_stress_curl.values
stressCurl26_10=ds26_10.wind_stress_curl.values
stressCurl26_11=ds26_11.wind_stress_curl.values

# %%
#Currents 25_1
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon25_1, Lat25_1, curMag25_1)
ax.contour(Lon25_1, Lat25_1, curMag25_1, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 25_1')
plt.show()
# Out:
# C:\Users\Anna\anaconda3\lib\site-packages\cartopy\mpl\gridliner.py:343: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '

# %%
#Currents 25_2
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon25_2, Lat25_2, curMag25_2)
ax.contour(Lon25_2, Lat25_2, curMag25_2, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 25_2')
plt.show()

# %%
#Currents 25_3
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon25_3, Lat25_3, curMag25_3)
ax.contour(Lon25_3, Lat25_3, curMag25_3, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 25_3')
plt.show()

# %%
#Currents 25_4
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon25_4, Lat25_4, curMag25_4)
ax.contour(Lon25_4, Lat25_4, curMag25_4, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 25_4')
plt.show()

# %%
#Currents 25_5
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon25_5, Lat25_5, curMag25_5)
ax.contour(Lon25_5, Lat25_5, curMag25_5, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 25_5')
plt.show()

# %%
#Currents 25_6
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon25_6, Lat25_6, curMag25_6)
ax.contour(Lon25_6, Lat25_6, curMag25_6, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 25_6')
plt.show()

# %%
#Currents 25_7
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon25_7, Lat25_7, curMag25_7)
ax.contour(Lon25_7, Lat25_7, curMag25_7, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 25_7')
plt.show()

# %%
#Currents 25_8
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon25_8, Lat25_8, curMag25_8)
ax.contour(Lon25_8, Lat25_8, curMag25_8, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 25_8')
plt.show()

# %%
#Currents 25_9
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon25_9, Lat25_9, curMag25_9)
ax.contour(Lon25_9, Lat25_9, curMag25_9, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 25_9')
plt.show()

# %%
#Currents 25_10
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon25_10, Lat25_10, curMag25_10)
ax.contour(Lon25_10, Lat25_10, curMag25_10, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 25_10')
plt.show()

# %%
#Currents 26_1
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon26_1, Lat26_1, curMag26_1)
ax.contour(Lon26_1, Lat26_1, curMag26_1, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 26_1')
plt.show()

# %%
#Currents 26_2
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon26_2, Lat26_2, curMag26_2)
ax.contour(Lon26_2, Lat26_2, curMag26_2, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 26_2')
plt.show()

# %%
#Currents 26_3
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon26_3, Lat26_3, curMag26_3)
ax.contour(Lon26_3, Lat26_3, curMag26_3, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 26_3')
plt.show()

# %%
#Currents 26_4
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon26_4, Lat26_4, curMag26_4)
ax.contour(Lon26_4, Lat26_4, curMag26_4, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 26_4')
plt.show()

# %%
#Currents 26_5
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon26_5, Lat26_5, curMag26_5)
ax.contour(Lon26_5, Lat26_5, curMag26_5, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 26_5')
plt.show()

# %%
#Currents 26_5
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon26_5, Lat26_5, curMag26_5)
ax.contour(Lon26_5, Lat26_5, curMag26_5, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 26_5')
plt.show()

# %%
#Currents 26_6
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon26_6, Lat26_6, curMag26_6)
ax.contour(Lon26_6, Lat26_6, curMag26_6, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 26_6')
plt.show()

# %%
#Currents 26_7
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon26_7, Lat26_7, curMag26_7)
ax.contour(Lon26_7, Lat26_7, curMag26_7, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 26_7')
plt.show()

# %%
#Currents 26_8
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon26_8, Lat26_8, curMag26_8)
ax.contour(Lon26_8, Lat26_8, curMag26_8, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 26_8')
plt.show()

# %%
#Currents 26_9
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon26_9, Lat26_9, curMag26_9)
ax.contour(Lon26_9, Lat26_9, curMag26_9, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 26_9')
plt.show()

# %%
#Currents 26_10
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon26_10, Lat26_10, curMag26_10)
ax.contour(Lon26_10, Lat26_10, curMag26_10, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 26_10')
plt.show()

# %%
#Currents 26_11
mapcrs = ccrs.PlateCarree()
fig = plt.figure(figsize=(10, 6), dpi=150)
ax = fig.add_subplot(111, projection=mapcrs)
ax.coastlines()
cs = ax.contourf(Lon26_11, Lat26_11, curMag26_11)
ax.contour(Lon26_11, Lat26_11, curMag26_11, colors = 'white', linewidths = 1, transform=ccrs.PlateCarree())
PCM=ax.get_children()[2]
plt.colorbar(cs, ax=ax, shrink = 0.5, label = 'm/s')
gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False, color = 'black')
plt.tight_layout()
gl.top_labels = False
gl.ylabels_right = False
plt.title('Current Magnitude 26_11')
plt.show()
